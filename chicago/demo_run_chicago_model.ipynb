# %%
# %run run_model_chicago_basic.py
# Out:
# CmdStanModel: name=chicago_basic_2.11
# 	 stan_file=/home/zl724/underreporting_public/chicago/stan_model/chicago_basic.stan
# 	 exe_file=/home/zl724/underreporting_public/chicago/stan_model/chicago_basic
# 	 compiler_options=stanc_options={}, cpp_options={'STAN_THREADS': True, 'STAN_CPP_OPTIMS': True}
# data_clean/aggdf_depCDOTDWM_compFalse_max100_samp-1.csv already exists
# Number of unique incidents, after merging with census tracts and dropping nans 575342
# Number of unique incidents, after merging with census demographics 565430
# 22:52:47 - cmdstanpy - INFO - CmdStan start processing
# Error standardizing OWNER_DEPARTMENT (most likely fine, not a float/int)
# OWNER_DEPARTMENT ['CDOT', 'DWM']
# chain 1 |                                                         | 00:00 Status
# chain 2 |                                                         | 00:00 Status
#
# chain 3 |                                                         | 00:00 Status
#
#
# chain 1 |████████████████████████| 00:04 Iteration:  51 / 150 [ 34%]  (Sampling)
# chain 2 |███████████████████                                      | 00:04 Status
# chain 2 |█████████████████▎        | 00:05 Iteration:   1 / 150 [  0%]  (Warmup)
# chain 2 |████████████████████████| 00:07 Iteration:  51 / 150 [ 34%]  (Sampling)
#
# chain 3 |███████████████████                                      | 00:07 Status
#
# chain 3 |█████████████████▎        | 00:08 Iteration:   1 / 150 [  0%]  (Warmup)
#
# chain 3 |████████████████████████| 00:11 Iteration:  51 / 150 [ 34%]  (Sampling)
#
#
# chain 4 |███████████████████                                      | 00:11 Status
#
#
# chain 4 |█████████████████▎        | 00:12 Iteration:   1 / 150 [  0%]  (Warmup)
#
#
# chain 1 |█████████████████████████████████████████████| 00:14 Sampling completed
# chain 2 |█████████████████████████████████████████████| 00:14 Sampling completed
# chain 3 |█████████████████████████████████████████████| 00:14 Sampling completed
# chain 4 |█████████████████████████████████████████████| 00:14 Sampling completed
# 22:53:02 - cmdstanpy - INFO - CmdStan done processing.
# X 1 ['OWNER_DEPARTMENT[T.DWM]']
# Category 25 ['SR_SHORT_CODE[AAD]', 'SR_SHORT_CODE[AAE]', 'SR_SHORT_CODE[AAF]', 'SR_SHORT_CODE[AAI]', 'SR_SHORT_CODE[CHECKFOR]']
# modelname 13 chica
# savelabel 2.11
# treesrootdirectory 2 ./
# iter_warmup 50
# iter_sampling 100
# max_incidents 500
# model_folder 11 stan_
# covariates_cont None
# settings None
# settings_name None
# standardization_dict {}
# saving y data from fits
# CmdStanMCMC: model=chicago_basic_model chains=4['method=sample', 'num_samples=100', 'num_warmup=50', 'thin=1', 'algorithm=hmc', 'adapt', 'engaged=1']
#  csv_files:
# 	./standata_chains/chicago_basic_2.11-20221122225247_1.csv
# 	./standata_chains/chicago_basic_2.11-20221122225247_2.csv
# 	./standata_chains/chicago_basic_2.11-20221122225247_3.csv
# 	./standata_chains/chicago_basic_2.11-20221122225247_4.csv
#  output_files:
# 	/tmp/tmpra0jtsqr/chicago_basic_model_vvwvu6x/chicago_basic_model-20221122225302_0-stdout.txt
# 	/tmp/tmpra0jtsqr/chicago_basic_model_vvwvu6x/chicago_basic_model-20221122225302_1-stdout.txt
# 	/tmp/tmpra0jtsqr/chicago_basic_model_vvwvu6x/chicago_basic_model-20221122225302_2-stdout.txt
# 	/tmp/tmpra0jtsqr/chicago_basic_model_vvwvu6x/chicago_basic_model-20221122225302_3-stdout.txt
# X 1 ['OWNER_DEPARTMENT[T.DWM]']
# Category 25 ['SR_SHORT_CODE[AAD]', 'SR_SHORT_CODE[AAE]', 'SR_SHORT_CODE[AAF]', 'SR_SHORT_CODE[AAI]', 'SR_SHORT_CODE[CHECKFOR]']
# modelname 13 chica
# savelabel 2.11
# treesrootdirectory 2 ./
# iter_warmup 50
# iter_sampling 100
# max_incidents 500
# model_folder 11 stan_
# covariates_cont None
# settings None
# settings_name None
# standardization_dict {}

# %%
import visualize.save_paper_things as spt
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

from latexify import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
aggdf = pd.read_csv('data_clean/aggdf_depCDOTDWM_compFalse_max100_samp-1.csv')
srcode = aggdf.groupby('SR_SHORT_CODE').SR_TYPE.first().reset_index()
srdict = dict(srcode.values)
dir_savefiles = 'stan_output/'
dir_plotoutput = 'plots/'

# %%
filename = ('prettysumdf_chicago_basic_2.11')
print(filename)
prettydf = pd.read_csv('{}{}.csv'.format(dir_savefiles, filename))

prettydf.head()

prettydf.R_hat = prettydf.R_hat.apply(lambda x: round(x, 1))
for row in range(len(prettydf)):
    cur_name = prettydf.name[row]
    if 'SR_SHORT_CODE' in cur_name:
            srsc = cur_name.split('[')[1].split(']')[0]
            srty = srdict.get(srsc, srsc)
            prettydf.name[row] = 'Category[{}]'.format(srty)
# prettydf.head()
prettydf.set_index('name', inplace=True)
prettydf.index.name = None
prettydf=prettydf[['Mean','StdDev','R_hat']]
prettydf
# Out:
# prettysumdf_chicago_basic_2.11
#                                                         Mean    StdDev  R_hat
# Intercept                                          -4.068317  0.406553    1.0
# Zero Inflation fraction                             0.587873  0.045245    1.0
# Category[Sewer Cave-In Inspection Request]         -1.300290  0.867439    1.0
# Category[Water On Street Complaint]                -2.259260  1.507420    1.0
# Category[Water in Basement Complaint]              -0.675051  1.539480    1.0
# Category[Alley Sewer Inspection Request]           -0.918919  1.745590    1.0
# Category[Sewer Cleaning Inspection Request]        -0.604121  1.332890    1.0
# Category[Protected Bike Lane - Debris Removal]     -0.303827  2.120780    1.0
# Category[Sidewalk Inspection Request]              -1.940690  0.684166    1.0
# Category[Sign Repair Request - Stop Sign]           1.970560  1.258380    1.0
# Category[Sign Repair Request - One Way Sign]        0.045893  2.029840    1.0
# Category[Sign Repair Request - All Other Signs]    -2.147060  0.941788    1.0
# Category[Bicycle Request/Complaint]                -0.429978  1.957380    1.0
# Category[Alley Pothole Complaint]                   0.481040  0.541620    1.0
# Category[Pothole in Street Complaint]               0.542524  0.416205    1.0
# Category[Alley Light Out Complaint]                 0.558260  0.490923    1.0
# Category[Traffic Signal Out Complaint]              2.695500  0.518368    1.0
# Category[Viaduct Light Out Complaint]              -0.079076  1.989650    1.0
# Category[Street Light Out Complaint]                1.665230  0.414953    1.0
# Category[Street Light Pole Damage Complaint]       -1.208260  1.535340    1.0
# Category[Street Light On During Day Complaint]     -1.027210  1.020020    1.0
# Category[Street Light Pole Door Missing Complaint] -0.242420  2.030380    1.0
# Category[Snow – Uncleared Sidewalk Complaint]       1.534760  0.726214    1.0
# Category[No Water Complaint]                       -0.432568  1.792420    1.0
# Category[Low Water Pressure Complaint]             -0.393059  1.858440    1.0
# Category[Open Fire Hydrant Complaint]               4.508080  0.575716    1.0
# Category[Water Quality Concern]                    -0.040046  1.810940    1.0
