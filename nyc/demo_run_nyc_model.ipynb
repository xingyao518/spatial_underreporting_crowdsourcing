# %%
# %run run_model_nyc_public_basic.py
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: /mnt/c/Users/Nikhi/OneDrive/src/2022_underreporting_public_actual/nyc/stan_modeling/models/basic_zeroinflated
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /mnt/c/Users/Nikhi/OneDrive/src/2022_underreporting_public_actual/nyc/run_model_nyc_public_basic.py:129
#     126 # parse the arguments
#     127 args = parser.parse_args()
# --> 129 run_model(modelname=args.modelname,
#     130           savelabel=args.savelabel,
#     131           treesrootdirectory=args.treesrootdirectory,
#     132           iter_warmup=args.iter_warmup,
#     133           iter_sampling=args.iter_sampling,
#     134           max_incidents=args.max_incidents,
#     135           model_folder=args.model_folder,
#     136           covariates_cont=covariates_cont_dict[args.covariates_cont_name],
#     137           settings_name=args.settings_name, force_compile=True, tract11_or_block12 = args.tract11_or_block12,
#     138           max_duration = args.max_duration, sample_size = args.sample_size)
#
# File /mnt/c/Users/Nikhi/OneDrive/src/2022_underreporting_public_actual/nyc/run_model_nyc_public_basic.py:47, in run_model(modelname, savelabel, treesrootdirectory, iter_warmup, iter_sampling, max_incidents, model_folder, covariates_cont, settings, settings_name, show_progress, force_compile, tract11_or_block12, max_duration, sample_size)
#      45 else:
#      46     comp = True
# ---> 47 model = CmdStanModel(stan_file=stan_file, #cpp_options=cpp_options,
#      48                      model_name=savefilename, compile = comp)
#      49 print(model)
#      51 # # Load/prepare data
#
# File ~/miniconda3/envs/underreportreplicate/lib/python3.11/site-packages/cmdstanpy/model.py:179, in CmdStanModel.__init__(self, model_name, stan_file, exe_file, compile, stanc_options, cpp_options, logger)
#     170     os.environ['PATH'] = ';'.join(
#     171         list(
#     172             OrderedDict.fromkeys(
#    (...)
#     175         )
#     176     )
#     178 if compile and self._exe_file is None:
# --> 179     self.compile()
#     180     if self._exe_file is None:
#     181         raise ValueError(
#     182             'Unable to compile Stan model file: {}.'.format(
#     183                 self._stan_file
#     184             )
#     185         )
#
# File ~/miniconda3/envs/underreportreplicate/lib/python3.11/site-packages/cmdstanpy/model.py:327, in CmdStanModel.compile(self, force, stanc_options, cpp_options, override_options)
#     325 cmd.append(Path(exe_file).as_posix())
#     326 try:
# --> 327     do_command(cmd, cmdstan_path(), logger=self._logger)
#     328 except RuntimeError as e:
#     329     self._logger.error(
#     330         'file %s, exception %s', stan_file, str(e)
#     331     )
#
# File ~/miniconda3/envs/underreportreplicate/lib/python3.11/site-packages/cmdstanpy/utils.py:157, in cmdstan_path()
#     155     cmdstan = os.path.join(cmdstan_dir, latest_cmdstan)
#     156     os.environ['CMDSTAN'] = cmdstan
# --> 157 validate_cmdstan_path(cmdstan)
#     158 return cmdstan
#
# File ~/miniconda3/envs/underreportreplicate/lib/python3.11/site-packages/cmdstanpy/utils.py:112, in validate_cmdstan_path(path)
#     110     raise ValueError('no such CmdStan directory {}'.format(path))
#     111 if not os.path.exists(os.path.join(path, 'bin', 'stanc' + EXTENSION)):
# --> 112     raise ValueError(
#     113         'no CmdStan binaries found, '
#     114         'run command line script "install_cmdstan"'
#     115     )
#
# ValueError: no CmdStan binaries found, run command line script "install_cmdstan"

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prepare_data.public_data_filtering import *
from visualize import save_paper_things as save_paper_things 

# %load_ext autoreload
# %autoreload 2
from generic.latexify import *
import seaborn as sns
import visualize.save_paper_things as spt
import pandas as pd
import os
dir_savefiles = 'stan_output/'
dir_plotoutput = 'plots/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
filename = ('prettysumdf_basic_zeroinflated_')
prettydf = pd.read_csv('{}{}.csv'.format(dir_savefiles, filename))

prettydf.head()
prettydf = prettydf.round(3)
prettydf.R_hat = prettydf.R_hat.apply(lambda x: round(x, 1))
if "logTPDBH" in prettydf.name.to_list():
    prettydf.name = prettydf.name.apply(lambda x: x.replace("logTPDBH", "Log(Tree Diameter at Breast Height)"))
# prettydf.head()
prettydf.set_index('name', inplace=True)
prettydf.index.name = None
prettydf=prettydf[['Mean','StdDev','5%', '50%', '95%', 'R_hat']]
prettydf
# Out:
#                                       Mean  StdDev     5%    50%    95%  R_hat
# Intercept                           -3.645   0.280 -4.115 -3.643 -3.189    1.0
# Zero Inflation fraction              0.503   0.044  0.428  0.505  0.575    1.0
# INSPCondtion[T.Dead]                 0.240   0.382 -0.394  0.250  0.858    1.0
# INSPCondtion[T.Excellent_Good]      -0.331   0.287 -0.812 -0.333  0.126    1.0
# INSPCondtion[T.Fair]                -0.548   0.251 -0.962 -0.533 -0.135    1.0
# INSP_RiskAssessment                  0.380   0.118  0.190  0.378  0.578    1.0
# Log(Tree Diameter at Breast Height)  0.205   0.126  0.002  0.208  0.408    1.0
# Borough[Bronx]                      -0.408   0.257 -0.832 -0.404  0.007    1.0
# Borough[Brooklyn]                    0.010   0.185 -0.302  0.013  0.319    1.0
# Borough[Manhattan]                   0.832   0.491  0.001  0.835  1.620    1.0
# Borough[Queens]                     -0.713   0.204 -1.062 -0.713 -0.381    1.0
# Borough[Staten Island]               0.278   0.298 -0.233  0.274  0.760    1.0
# Category[Hazard]                     1.686   0.161  1.421  1.679  1.955    1.0
# Category[Illegal Tree Damage]       -0.079   0.291 -0.573 -0.074  0.378    1.0
# Category[Prune]                      0.007   0.219 -0.360  0.003  0.351    1.0
# Category[Remove Tree]               -0.118   0.221 -0.497 -0.110  0.230    1.0
# Category[Root/Sewer/Sidewalk]       -1.495   0.371 -2.143 -1.473 -0.937    1.0
